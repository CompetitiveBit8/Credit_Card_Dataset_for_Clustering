# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
import warnings

# %%
warnings.filterwarnings(action='ignore')
df = pd.read_csv('CC_GENERAL.csv')
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %% [markdown]
# ### Data Engineering - (Adjusting for Null values)

# %%
X = df.drop(columns=df[['CUST_ID', 'TENURE']])
X.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# dtype: int64

# %%
X.fillna(method='ffill', inplace=True)
X.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %% [markdown]
# ### Scaling

# %%
scaler = MinMaxScaler()
X_transformed = scaler.fit_transform(X)

# %% [markdown]
# ### Initial Clustering

# %%
km = KMeans(n_clusters=4)
y_predict = km.fit_predict(X)
pd.DataFrame(y_predict).value_counts()
# Out:
# 1    6469
# 0    2292
# 2     129
# 3      60
# Name: count, dtype: int64

# %% [markdown]
# ### Checking through a range of K values to find the Best

# %%
K_range = range(1, 10)
sse = []

for k in K_range:
    km = KMeans(n_clusters=k)
    km.fit_predict(X)
    sse.append(km.inertia_)

# %% [markdown]
# ### Plotting of K values against the Sum of Squares

# %%
plt.figure(figsize=(8, 6))
plt.plot(K_range, sse)
plt.xlabel('sse')
plt.ylabel('K_range')
plt.title('Sum of Square')
plt.grid()
plt.show()

# %% [markdown]
# ###  Predicting using the K value derived form the graphical analysis

# %%
km = KMeans(n_clusters=2)
y_predict = km.fit_predict(X)
y_predict
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int32)

# %% [markdown]
# ### Table presentation with Label added

# %%
df['Labels'] = y_predict
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df['Labels'].value_counts()
# Out:
# Labels
# 0    7028
# 1    1922
# Name: count, dtype: int64
